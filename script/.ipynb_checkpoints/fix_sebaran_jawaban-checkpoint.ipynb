# %%
import mysql.connector
import pandas as pd 
import json
import numpy as np
import MySQLdb
import MySQLdb.cursors

# %%
db_thread = MySQLdb.connect("127.0.0.1", "root", "andhika", "usek_monev", cursorclass=MySQLdb.cursors.DictCursor)
cur_thread = db_thread.cursor()
print(cur_thread)
# Out:
# <MySQLdb.cursors.DictCursor object at 0x7ff2e418e5e0>

# %%
def get_soal(paket_id):
    sql = "SELECT * FROM soal where paket_id='%s'" % (paket_id)
    soal = pd.read_sql(sql, con=db_thread)
    soal = soal.set_index('id') 
    return soal

# %%
def get_ujian_siswa(paket_id):
    sql = "select * from ujian_siswa where paket_id='%s' and (status=2)" % (paket_id)
    cur_thread.execute(sql)
    ujian_siswa = cur_thread.fetchall()
    return ujian_siswa

# %%
def init_load_ujian(random_soal, random_jawaban, jawaban_siswa):
    soals = json.loads(random_soal)
    jawaban_posisi = json.loads(random_jawaban)
    jawabans = json.loads(jawaban_siswa)
    return soals, jawaban_posisi, jawabans

# %%
def init_posisi_jawaban():
    intochar={'1':"a",'2':"b",'3':"c",'4':"d",'5':"e"}
    arr_random= {
        "a" : intochar[jawaban_posisi[key][0]],
        "b" : intochar[jawaban_posisi[key][1]],
        "c" : intochar[jawaban_posisi[key][2]],
        "d" : intochar[jawaban_posisi[key][3]],
        "e" : intochar[jawaban_posisi[key][4]],
    }
    return arr_random

# %%
def sebaran_jawaban(arr_random, soal):
    if(arr_random[jawabans[key].lower()] == 'a'):
        soal.loc[soal_id, 'jawaban_a'] += 1 
    elif(arr_random[jawabans[key].lower()] == 'b'):
        soal.loc[soal_id, 'jawaban_b'] += 1
    elif(arr_random[jawabans[key].lower()] == 'c'): 
        soal.loc[soal_id, 'jawaban_c'] += 1
    elif(arr_random[jawabans[key].lower()] == 'd'):
        soal.loc[soal_id, 'jawaban_d'] += 1
    elif(arr_random[jawabans[key].lower()] == 'e'):
        soal.loc[soal_id, 'jawaban_e'] += 1

# %%
def update_hasil(soal, paket_id):
    for index, row in soal.iterrows():
        sql = "update soal set jawaban_a=%d, jawaban_b=%d, jawaban_c=%d, jawaban_d=%d, jawaban_e=%d, siswa_id_benar='%s', jumlah_benar_siswa=%d, jumlah_siswa=%d where id='%s'" %(row['jawaban_a'], row['jawaban_b'], row['jawaban_c'], row['jawaban_d'], row['jawaban_e'], row['siswa_id_benar'], row['jumlah_benar_siswa'], row['jumlah_siswa'], index)
        cur_thread.execute(sql)
    sql = "update ujian_siswa set status=3 where paket_id='%s' and (status=2)" % (paket['id'])
    cur_thread.execute(sql)
    sql = "update paket set status=1 where id='%s'" % (paket['id'])
    cur_thread.execute(sql)
    db_thread.commit()

# %%
cur_thread.execute("SELECT * from paket where status = 0")
pakets = cur_thread.fetchall()
for paket in pakets:
    soal = get_soal(paket['id'])
    ujian_siswas = get_ujian_siswa(paket['id'])
    print(len(ujian_siswas))
    for ujian_siswa in ujian_siswas:
        soals, jawaban_posisi, jawabans = init_load_ujian(ujian_siswa["random_soal"], ujian_siswa["random_jawaban"], ujian_siswa["jawaban_siswa"])
        for key, soal_id in enumerate(soals):
            siswa_id_benar = json.loads(soal.loc[soal_id, 'siswa_id_benar'])
            if (soal.loc[soal_id, 'tipe_soal'] == 'pilihan_ganda'): 
                arr_random = init_posisi_jawaban()
                if(jawabans[key] ==" "):
                    jawaban_benar=0
                else:
                    if (arr_random[jawabans[key].lower()] == soal.loc[soal_id, 'kunci_jawaban'].lower()): 
                        jawaban_benar=1
                        siswa_id_benar.append(ujian_siswa['id'])
                        s = json.dumps(siswa_id_benar)
                        soal.loc[soal_id, 'siswa_id_benar'] = s
                    else : 
                        jawaban_benar=0                
                    sebaran_jawaban(arr_random, soal)
                soal.loc[soal_id, 'jumlah_benar_siswa'] += jawaban_benar                
                soal.loc[soal_id, 'jumlah_siswa'] += 1
    update_hasil(soal, paket['id'])
    print("~DONE~ paket:", paket['nama'])
# Out:
# 23784
# ~DONE~ paket: K13_Pendidikan_Pancasila_dan_Kewarganegaraan_1
# 23899
# ~DONE~ paket: K13_Pendidikan_Pancasila_dan_Kewarganegaraan_2
# 15225
# ~DONE~ paket: K13_Pendidikan_Pancasila_dan_Kewarganegaraan_3
# 14986
# ~DONE~ paket: K13_Pendidikan_Pancasila_dan_Kewarganegaraan_4
# 1170
# ~DONE~ paket: K13_Pendidikan_Pancasila_dan_Kewarganegaraan_5
# 23687
# ~DONE~ paket: K13_Bahasa_Indonesia_MIPA/IPS/BAHASA_1
# 23634
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a43faaa208fc> in <module>
#      46                     elif(arr_random[jawabans[key].lower()] == 'e'):
#      47                         soal.loc[soal_id, 'jawaban_e'] += 1
# ---> 48                 soal.loc[soal_id, 'jumlah_benar_siswa'] += jawaban_benar
#      49                 soal.loc[soal_id, 'jumlah_siswa'] += 1
#      50     for index, row in soal.iterrows():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1645             if is_integer(info_idx):
#    1646                 info_idx = [info_idx]
# -> 1647             labels = item_labels[info_idx]
#    1648
#    1649             # Ensure we have something we can iterate over
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4109             key = np.asarray(key, dtype=bool)
#    4110
# -> 4111         result = getitem(key)
#    4112         if not is_scalar(result):
#    4113             if np.ndim(result) > 1:
#
# KeyboardInterrupt:

# %%
cur_thread.execute("SELECT * from paket where status = 0 limit 1")
pakets = cur_thread.fetchall()
for paket in pakets:
    print(paket['id'])
    soal = get_soal(paket['id'])
    ujian_siswas = get_ujian_siswa(paket['id'])
    print(len(ujian_siswas))
    for ujian_siswa in ujian_siswas:
#         print("ujian siswa id: ", ujian_siswa['id'])
        soals, jawaban_posisi, jawabans = init_load_ujian(ujian_siswa["random_soal"], ujian_siswa["random_jawaban"], ujian_siswa["jawaban_siswa"])
        print(soals)
        print(jawaban_posisi)
        print(jawabans)
        break
    print("~DONE~ paket:", paket['nama'])
# Out:
# 29187f70-5783-11ea-b304-86cbb67d2138
# 23634
# ['2918804a-5783-11ea-b304-86cbb67d2138', '2918802f-5783-11ea-b304-86cbb67d2138', '29187f83-5783-11ea-b304-86cbb67d2138', '29188016-5783-11ea-b304-86cbb67d2138', '29187fe7-5783-11ea-b304-86cbb67d2138', '29187fb0-5783-11ea-b304-86cbb67d2138', '2918804b-5783-11ea-b304-86cbb67d2138', '29188025-5783-11ea-b304-86cbb67d2138', '29187fc9-5783-11ea-b304-86cbb67d2138', '29187fec-5783-11ea-b304-86cbb67d2138', '29187ff6-5783-11ea-b304-86cbb67d2138', '29187f92-5783-11ea-b304-86cbb67d2138', '29188000-5783-11ea-b304-86cbb67d2138', '29187fa6-5783-11ea-b304-86cbb67d2138', '29187f7e-5783-11ea-b304-86cbb67d2138', '29187fba-5783-11ea-b304-86cbb67d2138', '29187fab-5783-11ea-b304-86cbb67d2138', '29187f79-5783-11ea-b304-86cbb67d2138', '2918802e-5783-11ea-b304-86cbb67d2138', '29187fc4-5783-11ea-b304-86cbb67d2138', '29187ffb-5783-11ea-b304-86cbb67d2138', '29187f88-5783-11ea-b304-86cbb67d2138', '29188041-5783-11ea-b304-86cbb67d2138', '29187fb5-5783-11ea-b304-86cbb67d2138', '29187fdd-5783-11ea-b304-86cbb67d2138', '29188037-5783-11ea-b304-86cbb67d2138', '29187fce-5783-11ea-b304-86cbb67d2138', '29187f9c-5783-11ea-b304-86cbb67d2138', '29188007-5783-11ea-b304-86cbb67d2138', '29187f8d-5783-11ea-b304-86cbb67d2138', '29187ff1-5783-11ea-b304-86cbb67d2138', '29188011-5783-11ea-b304-86cbb67d2138', '2918801b-5783-11ea-b304-86cbb67d2138', '29187f97-5783-11ea-b304-86cbb67d2138', '29188045-5783-11ea-b304-86cbb67d2138', '29188005-5783-11ea-b304-86cbb67d2138', '29187fd3-5783-11ea-b304-86cbb67d2138', '2918800c-5783-11ea-b304-86cbb67d2138', '29187fa1-5783-11ea-b304-86cbb67d2138', '29187fd8-5783-11ea-b304-86cbb67d2138', '29188020-5783-11ea-b304-86cbb67d2138', '2918803c-5783-11ea-b304-86cbb67d2138', '29187fbf-5783-11ea-b304-86cbb67d2138', '29187f71-5783-11ea-b304-86cbb67d2138', '29187fe2-5783-11ea-b304-86cbb67d2138']
# [['5', '3', '2', '4', '1'], ['1', '4', '3', '5', '2'], ['4', '2', '5', '1', '3'], ['3', '4', '1', '5', '2'], ['5', '4', '3', '2', '1'], ['3', '5', '4', '1', '2'], ['1', '3', '2', '4', '5'], ['2', '5', '1', '4', '3'], ['2', '1', '5', '4', '3'], ['2', '4', '5', '3', '1'], ['2', '5', '4', '1', '3'], ['2', '4', '3', '5', '1'], ['2', '4', '1', '3', '5'], ['5', '2', '1', '3', '4'], ['5', '3', '4', '2', '1'], ['1', '5', '2', '4', '3'], ['1', '5', '4', '3', '2'], ['1', '5', '2', '4', '3'], ['1', '5', '4', '3', '2'], ['4', '5', '2', '1', '3'], ['4', '5', '2', '1', '3'], ['2', '3', '5', '1', '4'], ['5', '1', '3', '4', '2'], ['3', '2', '1', '5', '4'], ['2', '3', '1', '5', '4'], ['4', '5', '3', '1', '2'], ['1', '3', '5', '2', '4'], ['1', '2', '3', '5', '4'], ['5', '2', '1', '3', '4'], ['4', '1', '2', '5', '3'], ['1', '2', '4', '3', '5'], ['4', '5', '2', '1', '3'], ['1', '3', '5', '4', '2'], ['2', '4', '1', '5', '3'], ['5', '2', '3', '1', '4'], ['4', '2', '1', '5', '3'], ['4', '1', '3', '2', '5'], ['4', '1', '5', '2', '3'], ['5', '1', '3', '2', '4'], ['4', '5', '3', '1', '2']]
# ['A', 'A', 'E', 'C', 'D', 'B', 'E', 'C', 'B', 'D', 'B', 'D', 'D', 'C', 'D', 'A', 'E', ' ', 'B', 'E', 'C', 'E', ' ', ' ', 'A', ' ', 'A', 'A', ' ', 'E', 'C', 'B', 'C', 'C', 'D', 'A', 'B', 'D', 'B', 'D']
# ~DONE~ paket: K13_Bahasa_Indonesia_MIPA/IPS/BAHASA_2

# %%
soal = get_soal('29187f70-5783-11ea-b304-86cbb67d2138')
soal.head(5)
# Out:
#                                                                               deskripsi  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138  <p><strong>Cermati teks ceramah berikut!</stro...
# 29187f79-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;"><strong>Cermati...
# 29187f7e-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;"><strong>Cermati...
# 29187f83-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;"><strong>Cermati...
# 29187f88-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;"><strong>Cermati...
#
#                                                                               pilihan_a  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138                                           <p>-</p>
# 29187f79-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">Pohon cemara ya...
# 29187f7e-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">sisa hasil prod...
# 29187f83-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">langkah awal li...
# 29187f88-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">kecepatan tsuna...
#
#                                                                               pilihan_b  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138                                           <p>-</p>
# 29187f79-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">Selain indah, b...
# 29187f7e-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">sisa proses pro...
# 29187f83-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">membiasakan keg...
# 29187f88-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">tsunami merusak...
#
#                                                                               pilihan_c  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138                                           <p>-</p>
# 29187f79-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">Tanaman hias ya...
# 29187f7e-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">cairan yang dib...
# 29187f83-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">literasi adalah...
# 29187f88-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">kecepatan berga...
#
#                                                                               pilihan_d  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138                                           <p>-</p>
# 29187f79-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">Semua bunga ter...
# 29187f7e-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">cairan yang tid...
# 29187f83-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">mewujudkan buda...
# 29187f88-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">kecepatan gelom...
#
#                                                                               pilihan_e  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138                                           <p>-</p>
# 29187f79-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">Petugas khusus ...
# 29187f7e-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">zat berbahaya b...
# 29187f83-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">menjadikan lite...
# 29187f88-5783-11ea-b304-86cbb67d2138  <p style="text-align:justify;">tsunami adalah ...
#
#                                      kunci_jawaban tingkat_kesulitan  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138             a              None
# 29187f79-5783-11ea-b304-86cbb67d2138             c              None
# 29187f7e-5783-11ea-b304-86cbb67d2138             b              None
# 29187f83-5783-11ea-b304-86cbb67d2138             a              None
# 29187f88-5783-11ea-b304-86cbb67d2138             d              None
#
#                                      level_kongnitif  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138            None
# 29187f79-5783-11ea-b304-86cbb67d2138            None
# 29187f7e-5783-11ea-b304-86cbb67d2138            None
# 29187f83-5783-11ea-b304-86cbb67d2138            None
# 29187f88-5783-11ea-b304-86cbb67d2138            None
#
#                                                                   paket_id  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138  29187f70-5783-11ea-b304-86cbb67d2138
# 29187f79-5783-11ea-b304-86cbb67d2138  29187f70-5783-11ea-b304-86cbb67d2138
# 29187f7e-5783-11ea-b304-86cbb67d2138  29187f70-5783-11ea-b304-86cbb67d2138
# 29187f83-5783-11ea-b304-86cbb67d2138  29187f70-5783-11ea-b304-86cbb67d2138
# 29187f88-5783-11ea-b304-86cbb67d2138  29187f70-5783-11ea-b304-86cbb67d2138
#
#                                       ... created_at          updated_at  \
# id                                    ...
# 29187f71-5783-11ea-b304-86cbb67d2138  ...       None 2020-02-14 14:02:35
# 29187f79-5783-11ea-b304-86cbb67d2138  ...       None 2020-02-14 09:03:39
# 29187f7e-5783-11ea-b304-86cbb67d2138  ...       None 2020-02-14 09:09:55
# 29187f83-5783-11ea-b304-86cbb67d2138  ...       None 2020-02-14 15:27:46
# 29187f88-5783-11ea-b304-86cbb67d2138  ...       None 2020-02-14 09:34:01
#
#                                      siswa_id_benar jawaban_a  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138             []         0
# 29187f79-5783-11ea-b304-86cbb67d2138             []         0
# 29187f7e-5783-11ea-b304-86cbb67d2138             []         0
# 29187f83-5783-11ea-b304-86cbb67d2138             []         0
# 29187f88-5783-11ea-b304-86cbb67d2138             []         0
#
#                                      jumlah_benar_siswa  jawaban_b  jawaban_c  \
# id
# 29187f71-5783-11ea-b304-86cbb67d2138                  0          0          0
# 29187f79-5783-11ea-b304-86cbb67d2138                  0          0          0
# 29187f7e-5783-11ea-b304-86cbb67d2138                  0          0          0
# 29187f83-5783-11ea-b304-86cbb67d2138                  0          0          0
# 29187f88-5783-11ea-b304-86cbb67d2138                  0          0          0
#
#                                       jawaban_d  jawaban_e  jumlah_siswa
# id
# 29187f71-5783-11ea-b304-86cbb67d2138          0          0             0
# 29187f79-5783-11ea-b304-86cbb67d2138          0          0             0
# 29187f7e-5783-11ea-b304-86cbb67d2138          0          0             0
# 29187f83-5783-11ea-b304-86cbb67d2138          0          0             0
# 29187f88-5783-11ea-b304-86cbb67d2138          0          0             0
#
# [5 rows x 22 columns]
