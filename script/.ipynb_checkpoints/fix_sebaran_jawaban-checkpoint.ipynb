# %%
import mysql.connector
import pandas as pd 
import json
import numpy as np
import MySQLdb
import MySQLdb.cursors

# %%
def get_soal(paket_id):
    sql = "SELECT * FROM soal where paket_id='%s'" % (paket_id)
    soal = pd.read_sql(sql, con=db_thread)
    soal = soal.set_index('id') 
    return soal

# %%
def get_ujian_siswa(paket_id):
    sql = "select * from ujian_siswa where paket_id='%s' and (status=2)" % (paket_id)
    cur_thread.execute(sql)
    ujian_siswa = cur_thread.fetchall()
    return ujian_siswa

# %%
def init_load_ujian(random_soal, random_jawaban, jawaban_siswa):
    soals = json.loads(random_soal)
    jawaban_posisi = json.loads(random_jawaban)
    jawabans = json.loads(jawaban_siswa)
    return soals, jawaban_posisi, jawabans

# %%
def init_posisi_jawaban():
    intochar={'1':"a",'2':"b",'3':"c",'4':"d",'5':"e"}
    arr_random= {
        "a" : intochar[jawaban_posisi[key][0]],
        "b" : intochar[jawaban_posisi[key][1]],
        "c" : intochar[jawaban_posisi[key][2]],
        "d" : intochar[jawaban_posisi[key][3]],
        "e" : intochar[jawaban_posisi[key][4]],
    }
    return arr_random

# %%
def sebaran_jawaban(arr_random, soal):
    if(arr_random[jawabans[key].lower()] == 'a'):
        soal.loc[soal_id, 'jawaban_a'] += 1 
    elif(arr_random[jawabans[key].lower()] == 'b'):
        soal.loc[soal_id, 'jawaban_b'] += 1
    elif(arr_random[jawabans[key].lower()] == 'c'): 
        soal.loc[soal_id, 'jawaban_c'] += 1
    elif(arr_random[jawabans[key].lower()] == 'd'):
        soal.loc[soal_id, 'jawaban_d'] += 1
    elif(arr_random[jawabans[key].lower()] == 'e'):
        soal.loc[soal_id, 'jawaban_e'] += 1

# %%
def update_hasil(soal, paket_id):
    for index, row in soal.iterrows():
        sql = "update soal set jawaban_a=%d, jawaban_b=%d, jawaban_c=%d, jawaban_d=%d, jawaban_e=%d, siswa_id_benar='%s', jumlah_benar_siswa=%d, jumlah_siswa=%d where id='%s'" %(row['jawaban_a'], row['jawaban_b'], row['jawaban_c'], row['jawaban_d'], row['jawaban_e'], row['siswa_id_benar'], row['jumlah_benar_siswa'], row['jumlah_siswa'], index)
        cur_thread.execute(sql)
    sql = "update ujian_siswa set status=3 where paket_id='%s' and (status=2)" % (paket['id'])
    cur_thread.execute(sql)
    sql = "update paket set status=1 where id='%s'" % (paket['id'])
    cur_thread.execute(sql)
    db_thread.commit()

# %%
db_thread = MySQLdb.connect("127.0.0.1", "root", "andhika", "usek_monev", cursorclass=MySQLdb.cursors.DictCursor)
cur_thread = db_thread.cursor()
print(cur_thread)
# Out:
# <MySQLdb.cursors.DictCursor object at 0x7fe9adaca460>

# %%
# cur_thread.execute("SELECT * from paket where id in (SELECT distinct paket_id from soal where jawaban_a =0 and jawaban_b = 0 and tipe_soal = 'pilihan_ganda')")
cur_thread.execute("SELECT * from paket where id in (SELECT distinct paket_id from soal where jawaban_a =0 and jawaban_b = 0 and tipe_soal = 'pilihan_ganda')")

pakets = cur_thread.fetchall()
for paket in pakets:
    soal = get_soal(paket['id'])
    ujian_siswas = get_ujian_siswa(paket['id'])
    print(len(ujian_siswas))
    count = 0
    for ujian_siswa in ujian_siswas:
        count+=1
        if count%1000==0:
            print(count)
        soals, jawaban_posisi, jawabans = init_load_ujian(ujian_siswa["random_soal"], ujian_siswa["random_jawaban"], ujian_siswa["jawaban_siswa"])
        for key, soal_id in enumerate(soals):
            siswa_id_benar = json.loads(soal.loc[soal_id, 'siswa_id_benar'])
            if (soal.loc[soal_id, 'tipe_soal'] == 'pilihan_ganda'): 
                arr_random = init_posisi_jawaban()
                if(jawabans[key] ==" "):
                    jawaban_benar=0
                else:
                    if (arr_random[jawabans[key].lower()] == soal.loc[soal_id, 'kunci_jawaban'].lower()): 
                        jawaban_benar=1
                        siswa_id_benar.append(ujian_siswa['id'])
                        s = json.dumps(siswa_id_benar)
                        soal.loc[soal_id, 'siswa_id_benar'] = s
                    else :
                        jawaban_benar=0                
                    sebaran_jawaban(arr_random, soal)
                soal.loc[soal_id, 'jumlah_benar_siswa'] += jawaban_benar                
                soal.loc[soal_id, 'jumlah_siswa'] += 1
    update_hasil(soal, paket['id'])
    print("~DONE~ paket:", paket['nama'])
# Out:
# 0
# ~DONE~ paket: KTSP_Pendidikan_Agama_Katolik_1
# 0
# ~DONE~ paket: KTSP_Bahasa_Indonesia_Bahasa_3
# 0
# ~DONE~ paket: KTSP_Bahasa_Indonesia_Bahasa_4
# 0
# ~DONE~ paket: KTSP_Bahasa_Indonesia_Bahasa_5
# 0
# ~DONE~ paket: KTSP_Sastra_Indonesia_5
# 0
# ~DONE~ paket: KTSP_Sastra_Indonesia_4
# 0
# ~DONE~ paket: KTSP_Matematika_IPA_5
# 0
# ~DONE~ paket: KTSP_Matematika_IPS_1
# 0
# ~DONE~ paket: KTSP_Matematika_IPS_2
# 0
# ~DONE~ paket: KTSP_Matematika_IPS_3
# 0
# ~DONE~ paket: KTSP_Matematika_IPS_4
# 0
# ~DONE~ paket: KTSP_Matematika_IPS_5
# 0
# ~DONE~ paket: KTSP_Bahasa_Inggris_3
# 0
# ~DONE~ paket: KTSP_Bahasa_Inggris_4
# 0
# ~DONE~ paket: KTSP_Bahasa_Inggris_5
# 0
# ~DONE~ paket: KTSP_Seni_Rupa_5
# 0
# ~DONE~ paket: KTSP_Seni_Musik_5
# 0
# ~DONE~ paket: KTSP_Seni_Tari_2
# 0
# ~DONE~ paket: KTSP_Seni_Tari_3
# 0
# ~DONE~ paket: KTSP_Seni_Tari_4
# 0
# ~DONE~ paket: KTSP_Seni_Tari_5
# 0
# ~DONE~ paket: KTSP_Seni_Teater_4
# 0
# ~DONE~ paket: KTSP_Seni_Teater_5
# 0
# ~DONE~ paket: KTSP_Pendidikan_Jasmani,_olahraga,_dan_Kesehatan_5
# 0
# ~DONE~ paket: KTSP_Teknologi_Informasi_dan_Komunikasi_5
# 0
# ~DONE~ paket: KTSP_Bahasa_Jerman_3
# 0
# ~DONE~ paket: KTSP_Bahasa_Jerman_4
# 0
# ~DONE~ paket: KTSP_Bahasa_Jerman_5
# 0
# ~DONE~ paket: KTSP_Bahasa_Jepang_5
# 0
# ~DONE~ paket: KTSP_Bahasa_Arab_3
# 0
# ~DONE~ paket: KTSP_Bahasa_Arab_4
# 0
# ~DONE~ paket: KTSP_Bahasa_Arab_5
# 0
# ~DONE~ paket: KTSP_Bahasa_Mandarin_1
# 0
# ~DONE~ paket: KTSP_Bahasa_Mandarin_2
# 0
# ~DONE~ paket: KTSP_Bahasa_Mandarin_5
# 0
# ~DONE~ paket: KTSP_Bahasa_Jawa_5
# 0
# ~DONE~ paket: KTSP_Bahasa_Madura_2
# 0
# ~DONE~ paket: KTSP_Bahasa_Madura_3
# 0
# ~DONE~ paket: KTSP_Bahasa_Madura_4
# 0
# ~DONE~ paket: KTSP_Bahasa_Madura_5
# 0
# ~DONE~ paket: KTSP_Biologi_5
# 0
# ~DONE~ paket: KTSP_Fisika_5
# 0
# ~DONE~ paket: KTSP_Kimia_2
# 0
# ~DONE~ paket: KTSP_Kimia_4
# 0
# ~DONE~ paket: KTSP_Kimia_5
# 0
# ~DONE~ paket: KTSP_Geografi_5
# 0
# ~DONE~ paket: KTSP_Ekonomi_5
# 0
# ~DONE~ paket: KTSP_Sosiologi_5
# 0
# ~DONE~ paket: KTSP_Antropologi_1
# 0
# ~DONE~ paket: KTSP_Antropologi_3
# 0
# ~DONE~ paket: KTSP_Antropologi_4
# 0
# ~DONE~ paket: KTSP_Antropologi_5
# 0
# ~DONE~ paket: KTSP_Matematika_BAHASA_3
# 0
# ~DONE~ paket: KTSP_Matematika_BAHASA_4
# 0
# ~DONE~ paket: KTSP_Matematika_BAHASA_5
# 0
# ~DONE~ paket: KTSP_Pendidikan_Agama_Islam_dan_Budi_Pekerti_2
# 0
# ~DONE~ paket: KTSP_Pendidikan_Agama_Hindu_dan_Budi_Pekerti_1
# 0
# ~DONE~ paket: KTSP_Pendidikan_Agama_Hindu_dan_Budi_Pekerti_2
# 0
# ~DONE~ paket: KTSP_Pendidikan_Agama_Hindu_dan_Budi_Pekerti_3
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Indonesia_3
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Indonesia_5
# 0
# ~DONE~ paket: K13_Matematika_Umum_5
# 0
# ~DONE~ paket: K13_Matematika_Peminatan_MIPA_5
# 0
# ~DONE~ paket: K13_Bahasa_Inggris_5
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Inggris_(Peminatan)_1
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Inggris_(Peminatan)_5
# 0
# ~DONE~ paket: K13_Sejarah_Peminatan_IPS_5
# 0
# ~DONE~ paket: K13_Seni_Rupa_5
# 0
# ~DONE~ paket: K13_Seni_Musik_5
# 0
# ~DONE~ paket: K13_Seni_Tari_5
# 0
# ~DONE~ paket: K13_Seni_Teater_5
# 0
# ~DONE~ paket: K13_Pendidikan_Jasmani,_olahraga,_dan_Kesehatan_5
# 0
# ~DONE~ paket: K13_Kerajinan_5
# 0
# ~DONE~ paket: K13_Rekayasa_5
# 0
# ~DONE~ paket: K13_Budidaya_5
# 0
# ~DONE~ paket: K13_Pengolahan_5
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Jerman_5
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Jepang_5
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Perancis_1
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Perancis_3
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Perancis_5
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Arab_5
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Mandarin_5
# 0
# ~DONE~ paket: K13_Bahasa_dan_Sastra_Korea_1
# 0
# ~DONE~ paket: K13_Bahasa_Jawa_5
# 0
# ~DONE~ paket: K13_Bahasa_Madura_2
# 0
# ~DONE~ paket: K13_Bahasa_Madura_3
# 0
# ~DONE~ paket: K13_Bahasa_Madura_4
# 0
# ~DONE~ paket: K13_Bahasa_Madura_5
# 0
# ~DONE~ paket: K13_Biologi_5
# 0
# ~DONE~ paket: K13_Fisika_5
# 0
# ~DONE~ paket: K13_Kimia_5
# 0
# ~DONE~ paket: K13_Geografi_5
# 0
# ~DONE~ paket: K13_Ekonomi_5
# 0
# ~DONE~ paket: K13_Sosiologi_5
# 0
# ~DONE~ paket: K13_Antropologi_5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-40368bb86287> in <module>
#       3 for paket in pakets:
#       4     soal = get_soal(paket['id'])
# ----> 5     ujian_siswas = get_ujian_siswa(paket['id'])
#       6     print(len(ujian_siswas))
#       7     count = 0
#
# <ipython-input-8-06ad5a481e28> in get_ujian_siswa(paket_id)
#       1 def get_ujian_siswa(paket_id):
#       2     sql = "select * from ujian_siswa where paket_id='%s' and (status=2)" % (paket_id)
# ----> 3     cur_thread.execute(sql)
#       4     ujian_siswa = cur_thread.fetchall()
#       5     return ujian_siswa
#
# ~/opt/anaconda3/lib/python3.8/site-packages/MySQLdb/cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# ~/opt/anaconda3/lib/python3.8/site-packages/MySQLdb/cursors.py in _query(self, q)
#     318         self._result = None
#     319         db.query(q)
# --> 320         self._do_get_result(db)
#     321         self._post_get_result()
#     322         self._executed = q
#
# ~/opt/anaconda3/lib/python3.8/site-packages/MySQLdb/cursors.py in _do_get_result(self, db)
#     143
#     144     def _do_get_result(self, db):
# --> 145         self._result = result = self._get_result()
#     146         if result is None:
#     147             self.description = self.description_flags = None
#
# ~/opt/anaconda3/lib/python3.8/site-packages/MySQLdb/cursors.py in _get_result(self)
#     350
#     351     def _get_result(self):
# --> 352         return self._get_db().store_result()
#     353
#     354     def _post_get_result(self):
#
# KeyboardInterrupt:
